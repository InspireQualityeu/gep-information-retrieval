# %%
import pandas as pd
import os
import re


# Specify the directory path. Becarefull with slash and backslash.

directory_path = r'define_directory_for_reading'

# Check if the directory exists
if os.path.exists(directory_path):
    # List all files in the directory with .txt extension
    txt_files = [f for f in os.listdir(directory_path) if f.endswith('.txt')]
    
    # Initialize lists to store data
    text_data = []
    pdf_names = []
    
    # Loop through each .txt file and read its contents
    for txt_file in txt_files:
        file_path = os.path.join(directory_path, txt_file)
        with open(file_path, 'r', encoding='utf-8') as file:
            file_contents = file.read()
            # Append the file name (without extension) to pdf_names
            pdf_name_without_extension = os.path.splitext(txt_file)[0]
            pdf_names.append(pdf_name_without_extension)
            # Append the file contents to text_data
            text_data.append(file_contents)

    # Create a DataFrame
    df = pd.DataFrame({'PDF_Name': pdf_names, 'Text': text_data})
    
    # Print the DataFrame
    print(df)
else:
    print(f"The directory {directory_path} does not exist.")

# %%
#Indicators Prevelance

##Horizon Europe - Indicator 3

import re

def find_Horizon_Europe(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["Horizon Europe", "Eligibility criterion", "Horizon research funding"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_3_Horizon_Europe'] = df['Text'].apply(find_Horizon_Europe, words=words_to_find)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 23
#      20 words_to_find = [word.lower() for word in words_to_find]
#      22 # Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
# ---> 23 df['Indicator_3_Horizon_Europe'] = df['Text'].apply(find_Horizon_Europe, words=words_to_find)
#
# NameError: name 'df' is not defined

# %%
###The time plan of the current plan - Indicator 5

# Define a regular expression pattern to match dates in the format "xxxx-xxxx"

date_pattern_v1 = r'\s*?\d{4}\s*?[\u002D\u058A\u05BE\u2010\u2011\u2012\u2013\u2014\u2015\u2E3A\u2E3B\uFE58\uFE63\uFF0D]\s*?\d{4}\s*?'

# Function to extract date from text
def extract_date_v1(text):
    match = re.search(date_pattern_v1, text)
    if match:
        return match.group(0)
    else:
        return None

# Apply the function to create a new 'time frame' column
df['Indicator_5_the_time_frame_of_the_current_plan'] = df['Text'].apply(extract_date_v1)

# %%
##Areas of Activities - Indicator 6

# %%
### Awareness Rising - Indicator 6.1

def find_Awareness_Rising(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["awareness training", "raise awareness", "increase awareness", "awareness-raising", "unconscious bias", "gender stereotypes", "recruitment training", "selection training", "sensitisation", "sensitivity to gender equality", 
                 "capacity-building training", "gender equality training", "training sessions", "training of the recruitment committees", "raising awareness", "training courses", "training events", 
                 "awareness and competence development", "awareness of gender issues", "employee awareness", "gender equality awareness", "gender awareness", "unconscious gender bias", "awareness of gender equality"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_6.1_Awareness_Rising'] = df['Text'].apply(find_Awareness_Rising, words=words_to_find)

# %%
### Work-Life Balance - Indicator 6.2

def find_Work_Life_Balance_and_organisational_culture(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["Work-life balance", "caring responsibilities", "care responsibilities", "Parental leave", "Family leave", "Maternity leave", "Paternity leave", "Career breaks", 
                 "Family-related break", "returner", "Parents", "careers", "Flexible working time", "flexibility of working time", "working time arrangements", "Remote working", 
                 "Hybrid working", "Family audit", "Childcare facilities", "Childcare", "Nursery", "Day care center", "Family support", "Dignity at work" ,"Inclusive language", 
                 "Gender-sensitive language", "Gendered language", "Welcoming" ,"Workload", "Open work environment" ,"Inclusive work environment", "family life", "child care leave"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_6.2_Work_Life_Balance_and_organisational_culture'] = df['Text'].apply(find_Work_Life_Balance_and_organisational_culture, words=words_to_find)

# %%
### Leadership_Decision_Making - Indicator 6.3

def find_Leadership_Decision_Making(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["Gender balance" ,"decision-making bodies", "decision-making body", "Academic leadership", "Administrative leadership" ,"Representation", "Leadership position",
                 "Gender quota" ,"Gender balance" ,"Election procedures", "Leadership competences", "leadership development", "decision-making process"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_6.3_Leadership_Decision_Making'] = df['Text'].apply(find_Leadership_Decision_Making, words=words_to_find)

# %%
### Recruitment_and_Career - Indicator 6.4

def find_Recruitment_and_Career(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["Recruitment procedure", "Recruitment committee", "Recruitment panel", "Selection process", "Selection procedure", "Promotion comittee", 
                 "Career progression", "Career development", "Evaluation criteria", "Appraisal criteria", "performance assessment", "performance appraisal", 
                 "mentoring", "career ladder", "career path", "career advancement", "recruitment process", "gender equality in recruitment", "recruitment transparancy"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_6.4_Recruitment_and_Career'] = df['Text'].apply(find_Recruitment_and_Career, words=words_to_find)

# %%
### Gender_Based_Violence - Indicator 6.5

def find_Gender_Based_Violence(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["Gender-based violence", "gender based violence", "sexual harassment", "harassment", "sexual violence", "bullying",
                 "gender-based discrimination", "sexualized violence", "sexualised violence"]


# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]
# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_6.5_Gender_Based_Violence'] = df['Text'].apply(find_Gender_Based_Violence, words=words_to_find)

# %%
### Gender_Dimension - Indicator 6.6

def find_Gender_Dimension(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)
words_to_find = ["Gender dimension", "Sex analysis", "Gender analysis", "Gender impact assessment", "Incorporating gender", "Incorporating sex", 
                 "Research funding", "Research priorities", "Teaching activities", "Educational activities", "Gender perspective", "Gender in research", "Gender in teaching"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_6.6_Gender_Dimension'] = df['Text'].apply(find_Gender_Dimension, words=words_to_find)

# %%
### Integration of Intersectional Approaches - Indicator 7
###Intersectional Term - Indicator 7.1

def find_Intersectional(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Intersectional", "Intersectionality"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_7.1_Intersectional'] = df['Text'].apply(find_Intersectional, words=words_to_find)

# %%
###Diversity Term - Indicator 7.2

def find_Diversity(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Diversity"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_7.2_Diversity'] = df['Text'].apply(find_Diversity, words=words_to_find)

# %%
###Gender_diversity - Indicator 7.4

def find_Gender_Diversity(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Non-binary", "Gender-Diverse", "trans", "transgender", "gender diversity", "gender identity", "all genders", "other genders"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_7.4_Gender_Diversity'] = df['Text'].apply(find_Gender_Diversity, words=words_to_find)

# %%
###What Inequalities are adressed? - Indicator 8
###Race - Indicator 8.1

def find_Race(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Race", "ethnic background", "ethnic minorities", "migrant", "immigrant", "ethnic origin", "ethnicity", "black", "people of color", "people of colour", "poc", "bipoc", "indigenous", "minority ethnic"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.1_Race'] = df['Text'].apply(find_Race, words=words_to_find)

# %%
###Nationality - Indicator 8.2

def find_Nationality(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Nationality"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.2_Nationality'] = df['Text'].apply(find_Nationality, words=words_to_find)

# %%
###NReligion - Indicator 8.3

def find_Religion(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Religion", "Religious", "religions", "religiose", "religiosity", "religiously", "Muslim", "Jewish"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.3_Religion'] = df['Text'].apply(find_Religion, words=words_to_find)

# %%
###Class - Indicator 8.4

def find_Class(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Class", "social background", "first generation", "socio-economic status"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.4_Class'] = df['Text'].apply(find_Class, words=words_to_find)

# %%
###Age - Indicator 8.5

def find_Age(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Age"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.5_Age'] = df['Text'].apply(find_Age, words=words_to_find)

# %%
###Sexual_Orientation - Indicator 8.6

def find_Sexual_orientation(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Sexual orientation", "gay", "lesbian", "bisexual", "queer", "LGBTIQ", "sexual identity", "LGBTI"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.6_Sexual_orientation'] = df['Text'].apply(find_Sexual_orientation, words=words_to_find)

# %%
###Disability - Indicator 8.7

def find_Disability(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Disability", "disable", "disabled", "disabling", "disablism", "disablist", "ableism", "physical impairment", "physical limitation", "chronic disease"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_8.7_Disability'] = df['Text'].apply(find_Disability, words=words_to_find)

# %%
## Gender Equality Unit - Indicator 9
###Specialized staff - Indicator 9.1

def find_Specialized_staff_comittees(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Gender equality officer", "Gender equality commissioner",	"Equal opportunities officer", "Equal opportunity officer", "Equal opportunity commissioner", 
                 "Gender equality unit", "Gender equality team", "Equality officer", "EDI manager", "Diversity manager", "Diversity team" "EDI committee", "EDI director",
                 "working group", "GEP working group", "Gender equality working group", "Equality committee", "EDI committee", "Athena SWAN steering group", "EDI joint advisory committee",
                 "Gender equality steering group", "Senate commission for gender equality", "Senate commission for equality", "Senate commission for equal opportunities"]
# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_9.1_Specialized_staff_comittees'] = df['Text'].apply(find_Specialized_staff_comittees, words=words_to_find)

# %%
##Collection and Publicatin of sex-Disaggregated data - Indicator 10
###Data_Collection - Indicator 10.1

def find_Data_Collection(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Data collection",	"Collection of data", "sex-disaggregated data", "gender statistics", "gender data", "collecting data", 
                 "share of women", "share of men", "proportion of women", "proportion of men", "regular statistics"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_10.1_Data_Collection'] = df['Text'].apply(find_Data_Collection, words=words_to_find)

# %%
###Data_Publication- Indicator 10.1

def find_Data_Publication(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [re.escape(word) for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["gender data report", "gender equality report", "equality monitoring report", "EDI reporting", "Progress report",
                 "publication of data", "gender distribution", "distribution of positions", "distribution of academic positions", "annual report"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_10.2_Data_Publication'] = df['Text'].apply(find_Data_Publication, words=words_to_find)

# %%
###ystem for monitoring and Controlling - Indicator 11

def find_System_Monitoring_Controlling(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]


    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Monitoring", "Controlling", "Evaluation", "quality assurance", "gender equality analysis", "gender equality audit",
                 "gender equality assessment", "equality analysis", "equality audit", "equality assessment", "self-assessment",
                 "EDI surveying", "Equality impact assessment"]


# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_11_System_Monitoring_Controlling'] = df['Text'].apply(find_System_Monitoring_Controlling, words=words_to_find)

# %%
##Impact Indicator - Indicator 12
###Understanding Impact - Indicator 12.1

def find_Understanding_Impact(text, words):
    # Convert the text to lowercase and create a regex pattern for each word/phrase, ensuring it stands alone
    patterns = [r'\b' + re.escape(word) + r'\b' for word in words]

    # Convert the text to lowercase and find the standalone words
    found_words = {word for pattern in patterns for word in re.findall(pattern, text.lower(), re.IGNORECASE)}

    return 'Yes' if found_words else 'No'

# List of words to find (case-insensitive)

words_to_find = ["Impact", "Effect", "outcome", "output"]

# Convert all words in words_to_find to lowercase
words_to_find = [word.lower() for word in words_to_find]

# Apply the find_Gender_Dimension function to each row and create the 'Indicator_6.6_Gender_Dimension' column
df['Indicator_12_Understanding_Impact'] = df['Text'].apply(find_Understanding_Impact, words=words_to_find)

# %%
# Specify the Excel file name, sheet name and the directory

directory = r'define_directory_for_saving'
excel_file = directory + r'\your_output.xlsx'
sheet_name = 'Sheet1'

# Write the DataFrame to the Excel file
df.to_excel(excel_file, sheet_name=sheet_name, index=False)
